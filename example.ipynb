# %%
import warnings
warnings.filterwarnings('ignore')

import json

import numpy as np
import pandas as pd

import spacy
import en_core_web_sm
import pyinflect

import gensim.downloader as api
from english import EnglishEx
from sentence_splitter import SentenceSplitter
# Out:
# 2023-07-13 20:07:40.525875: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-13 20:07:40.526982: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-13 20:07:40.549014: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-13 20:07:40.549483: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-13 20:07:40.906731: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-13 20:07:41.252743: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2023-07-13 20:07:41.252761: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:168] retrieving CUDA diagnostic information for host: artem-MS-7E01
# 2023-07-13 20:07:41.252764: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:175] hostname: artem-MS-7E01
# 2023-07-13 20:07:41.252826: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:199] libcuda reported version is: 535.54.3
# 2023-07-13 20:07:41.252834: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:203] kernel reported version is: 535.54.3
# 2023-07-13 20:07:41.252836: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:309] kernel version seems to match DSO: 535.54.3

# %%
file = open('Little_Red_Riding_Hood_Charles_Perrault.txt')
txt = file.read()

# %%
ex = EnglishEx(10, txt)

# %%
df = ex.df_maker()

# %%
tasks = ex.type_ex(df)

# %%
tasks
# Out:
#                                            sentences            object  \
# 0  The French title of this famous tale ___ " Le ...                is
# 1  The wolf , seeing her come since in , said to ...                in
# 2  " Oh I believe say , " answered Little Red Rid...               say
# 3                                                     Charles Perrault
# 4         " Grandmother , what ___ legs you have ! "               big
# 5  Little Red Riding Hood , hearing the big voice...        grandchild
# 6  " All the better to hear with , my children ch...             child
# 7         " Grandmother , what ___ ears you have ! "               big
# 8                                " Who ___ there ? "                's
# 9  Her mother was excessively fond of her ; and h...             doted
#
#                                              options            answer  \
# 0                               [---, is, this, one]                is
# 1                              [---, ,, upon, since]             since
# 2                          [---, ", Little, believe]           believe
# 3  [---, Charles Perrault, Charles Perrault, Char...  Charles Perrault
# 4                               [---, big, n't, lot]               big
# 5     [---, grandchild, great-grandchild, firstborn]        grandchild
# 6                              [---, ., ,, children]          children
# 7                               [---, big, n't, lot]               big
# 8                                [---, 's, has, its]                's
# 9                                                                doted
#
#                           describe result  total          type
# 0  Выбери правильную форму глагола     []      0     tobe_verb
# 1              Выбери лишние слово     []      0   delete_word
# 2              Выбери лишние слово     []      0   delete_word
# 3    Выбери правильное предложение     []      0   select_sent
# 4                   Выберите слово     []      0   select_word
# 5                   Выберите слово     []      0   select_word
# 6              Выбери лишние слово     []      0   delete_word
# 7                   Выберите слово     []      0   select_word
# 8  Выбери правильную форму глагола     []      0     tobe_verb
# 9                Заполните пропуск     []      0  missing_word
